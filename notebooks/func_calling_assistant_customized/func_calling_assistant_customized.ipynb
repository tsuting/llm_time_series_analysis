# %% [markdown]
# This notebooks shows how to use [OpenAI assistant](https://platform.openai.com/docs/guides/function-calling) to do function calling.
# - steps:
#   - create an assistant (LLM + a lot of predefined func)
#   - call LLM to see which predefined func to use and what are the input params
#   - return the results to LLM
#   - get the answer from LLM
# - the input data are: [`air_passengers.csv`](../../data/air_passengers.csv), [`melbourne_temp.csv`](../../data/melbourne_temp.csv), [`nyc_taxi.csv`](../../data/nyc_taxi.csv)
# - the question is: [`easy_precise_questions.csv`](../../data/easy_precise_questions.csv)

# %%
from openai import AzureOpenAI
from dotenv import load_dotenv
import os
import pandas as pd

from pathlib import Path
from tqdm.notebook import tqdm
import sys

module_path = os.path.abspath(os.path.join(".."))
if module_path not in sys.path:
    sys.path.append(module_path)

from utils.utils import convert_types, eval
from utils.vars import DATA_DIR, EXCEPT_FILES, QUESTION_FILES
from utils.assistants import AzureOpenAIAssistant
from utils.customized_func_tools import (
    TOOLS,
)

load_dotenv()

ASSISTANT_NAME_PREFIX = "customized_func"

# %%
# get the client object
client = AzureOpenAI(
    api_key=os.getenv("AZURE_OPENAI_API_KEY"),
    api_version="2024-05-01-preview",  # only support this version
    azure_endpoint=os.getenv("AZURE_OPENAI_ENDPOINT"),
)
assistant = AzureOpenAIAssistant(client=client)

# %%
display(assistant.list_all_assistants())
# Out:
#                               id  created_at description  \
# 0  asst_zp1VbRMednIpC4Zl65nDt4Hk  1735007424        None
# 1  asst_5E83wPdW0Lg32VmhhJizKPr4  1735007326        None
# 2  asst_VGmOogPrbDPXHIJeUbVmWWzZ  1734137131        None
# 3  asst_0Qc1dyLAY7XD3dKLqIkNJ45l  1734137012        None
# 4  asst_hTacjFmXp0wJW7cTacgiIaVm  1734136870        None
# 5  asst_x4c0gSGzdmoljHa4DrmZjPZO  1734135165        None
#
#                                         instructions metadata   model  \
# 0  You are a data scientist in univariate time se...       {}  gpt-4o
# 1  You are a data scientist in univariate time se...       {}  gpt-4o
# 2  You are a data scientist in univariate time se...       {}  gpt-4o
# 3  You are a data scientist in univariate time se...       {}  gpt-4o
# 4  You are a data scientist in univariate time se...       {}  gpt-4o
# 5  You are a python expert in univariate time ser...       {}  gpt-4o
#
#                               name     object  \
# 0   customized_func_melbourne_temp  assistant
# 1   customized_func_air_passengers  assistant
# 2        code_interpreter_nyc_taxi  assistant
# 3  code_interpreter_melbourne_temp  assistant
# 4  code_interpreter_air_passengers  assistant
# 5   code_interpreter_nyc_taxi_plot  assistant
#
#                                                tools response_format  \
# 0  [{'function': {'name': 'get_time_col_and_targe...            auto
# 1  [{'function': {'name': 'get_time_col_and_targe...            auto
# 2                     [{'type': 'code_interpreter'}]            auto
# 3                     [{'type': 'code_interpreter'}]            auto
# 4                     [{'type': 'code_interpreter'}]            auto
# 5                     [{'type': 'code_interpreter'}]            auto
#
#    temperature                                     tool_resources  top_p
# 0          0.0                                                 {}    1.0
# 1          0.0                                                 {}    1.0
# 2          0.0  {'code_interpreter': {'file_ids': ['assistant-...    1.0
# 3          0.0  {'code_interpreter': {'file_ids': ['assistant-...    1.0
# 4          0.0  {'code_interpreter': {'file_ids': ['assistant-...    1.0
# 5          0.0  {'code_interpreter': {'file_ids': ['assistant-...    1.0

# %%
# delete assistant
assistant.delete_assistant(name=f"{ASSISTANT_NAME_PREFIX}_nyc_taxi")
assistant.delete_assistant(name=f"{ASSISTANT_NAME_PREFIX}_melbourne_temp")
assistant.delete_assistant(name=f"{ASSISTANT_NAME_PREFIX}_air_passengers")

display(assistant.list_all_assistants())
# Out:
#                               id  created_at description  \
# 0  asst_VGmOogPrbDPXHIJeUbVmWWzZ  1734137131        None
# 1  asst_0Qc1dyLAY7XD3dKLqIkNJ45l  1734137012        None
# 2  asst_hTacjFmXp0wJW7cTacgiIaVm  1734136870        None
# 3  asst_x4c0gSGzdmoljHa4DrmZjPZO  1734135165        None
#
#                                         instructions metadata   model  \
# 0  You are a data scientist in univariate time se...       {}  gpt-4o
# 1  You are a data scientist in univariate time se...       {}  gpt-4o
# 2  You are a data scientist in univariate time se...       {}  gpt-4o
# 3  You are a python expert in univariate time ser...       {}  gpt-4o
#
#                               name     object                           tools  \
# 0        code_interpreter_nyc_taxi  assistant  [{'type': 'code_interpreter'}]
# 1  code_interpreter_melbourne_temp  assistant  [{'type': 'code_interpreter'}]
# 2  code_interpreter_air_passengers  assistant  [{'type': 'code_interpreter'}]
# 3   code_interpreter_nyc_taxi_plot  assistant  [{'type': 'code_interpreter'}]
#
#   response_format  temperature  \
# 0            auto          0.0
# 1            auto          0.0
# 2            auto          0.0
# 3            auto          0.0
#
#                                       tool_resources  top_p
# 0  {'code_interpreter': {'file_ids': ['assistant-...    1.0
# 1  {'code_interpreter': {'file_ids': ['assistant-...    1.0
# 2  {'code_interpreter': {'file_ids': ['assistant-...    1.0
# 3  {'code_interpreter': {'file_ids': ['assistant-...    1.0

# %% [markdown]
# ## Run 3 files x all questions

# %%
prompt_path = "prompts/prompt.jinja2"

# %%
# cons
# cannot pass a lot of values to the prompt due to token limit
# really need to design the function properly

# %%
df_result = []

for question_path in QUESTION_FILES:
    df_questions = pd.read_csv(question_path)
    for file_path in Path(DATA_DIR).glob("*.csv"):
        if file_path.name in EXCEPT_FILES:
            continue
        print(f"file: {file_path.name}")
        assistant_id = assistant.create_or_retrieve(
            prompt_path=prompt_path,
            assistant_name=f"{ASSISTANT_NAME_PREFIX}_{file_path.stem}",
            tools=TOOLS,
            tool_resources=None,
            prompt_args={"file_path": file_path},
        )
        for _, row in tqdm(df_questions.iterrows(), total=len(df_questions)):
            question = row["question"]
            answer_true = row[Path(file_path).name]

            result = assistant.ask_a_question(
                question=question, assistant_id=assistant_id, tools=TOOLS
            )

            df_result.append(
                {
                    **result,
                    "file": file_path.name,
                    "question_file": question_path.name,
                    "answer_true": convert_types(answer_true),
                }
            )
# Out:
# file: air_passengers.csv
#   0%|          | 0/16 [00:00<?, ?it/s]
# file: melbourne_temp.csv
#   0%|          | 0/16 [00:00<?, ?it/s]
# file: nyc_taxi.csv
#   0%|          | 0/16 [00:00<?, ?it/s]
# file: air_passengers.csv
#   0%|          | 0/16 [00:00<?, ?it/s]
# JSONDecodeError: Yes.
# JSONDecodeError: No
# 18:37:01 - cmdstanpy - INFO - Chain [1] start processing
# 18:37:01 - cmdstanpy - INFO - Chain [1] done processing
# file: melbourne_temp.csv
#   0%|          | 0/16 [00:00<?, ?it/s]
# JSONDecodeError: No
# JSONDecodeError: No
# 18:38:25 - cmdstanpy - INFO - Chain [1] start processing
# 18:38:26 - cmdstanpy - INFO - Chain [1] done processing
# file: nyc_taxi.csv
#   0%|          | 0/16 [00:00<?, ?it/s]
# JSONDecodeError: Yes
# JSONDecodeError: No
# JSONDecodeError: Yes.
# JSONDecodeError: No
# 18:39:58 - cmdstanpy - INFO - Chain [1] start processing
# 18:39:59 - cmdstanpy - INFO - Chain [1] done processing

# %%
# how about code interpreter + function calling?

# %%
# Thoughts: write function and define each function clearly is important
# return results are difficult e.g., filter_by_weekdays() -> call the other function. if it's just a number or a string, it's fine
# - pros: things are fixable either function or the prompt
# more and more function, more prompt tokens

# %%
# eval
df_result = pd.DataFrame(df_result)

# loop through each file
eval(df=df_result, details=True)
# Out:
# ==================================================
# Question file: easy_questions.csv; File: air_passengers.csv; Accuracy: 1.0
# ==================================================
# ==================================================
# Question file: easy_questions.csv; File: melbourne_temp.csv; Accuracy: 0.9375
# ==================================================
# question: Tell me the end date of the given time series data.
# answer_pred: 1990-01-11 00:00:00
# answer_true: 1990-12-31 00:00:00
# messages: user: Tell me the end date of the given time series data.
# assistant: {"output": "1990-01-11"}
# steps: [{'name': 'get_time_col_and_target_col', 'input': None, 'output': "{'target_col': 'Daily minimum temperatures', 'time_col': 'Date'}", 'args': '{"file_path":"../../data/melbourne_temp.csv"}'}]
# **************************************************
# ==================================================
# Question file: easy_questions.csv; File: nyc_taxi.csv; Accuracy: 1.0
# ==================================================
# ==================================================
# Question file: medium_questions.csv; File: air_passengers.csv; Accuracy: 0.8125
# ==================================================
# question: Does the dataset show any autocorrelation?
# answer_pred: Yes.
# answer_true: Yes
# messages: user: Does the dataset show any autocorrelation?
# assistant: Yes.
# steps: [{'name': 'get_index_by_calc_acf_or_pacf', 'input': None, 'output': '1', 'args': '{"file_path":"../../data/air_passengers.csv","col_name":"target_col","start_lag":1,"end_lag":10,"type_of_correlation":"acf","return_max_or_min":"max"}'}]
# **************************************************
# question: Which lagging value has the weakest absolute correlation with the target variable among the values from 1 to 10 if we don't accounting for any influence from other data points?
# answer_pred: 8.0
# answer_true: 6.0
# messages: user: Which lagging value has the weakest absolute correlation with the target variable among the values from 1 to 10 if we don't accounting for any influence from other data points?
# assistant: {"output": "8"}
# steps: [{'name': 'get_index_by_calc_acf_or_pacf', 'input': None, 'output': '8', 'args': '{"file_path":"../../data/air_passengers.csv","col_name":"target_col","start_lag":1,"end_lag":10,"type_of_correlation":"acf","return_max_or_min":"min"}'}]
# **************************************************
# question: Forecast the last 5 data points in the time column using naive model.
# answer_pred: 622.0_622.0_622.0_622.0_622.0
# answer_true: 622.00_622.00_622.00_622.00_622.00
# messages: user: Forecast the last 5 data points in the time column using naive model.
# assistant: {"output": "622.0_622.0_622.0_622.0_622.0"}
# steps: [{'name': 'forecast_last_n_data', 'input': None, 'output': '[622.0, 622.0, 622.0, 622.0, 622.0]', 'args': '{"file_path":"../../data/air_passengers.csv","model_name":"naive","forecast_horizon":5}'}]
# **************************************************
# ==================================================
# Question file: medium_questions.csv; File: melbourne_temp.csv; Accuracy: 0.9375
# ==================================================
# question: Forecast the last 5 data points in the time column using Prophet model
# answer_pred: 14.57_14.6_14.62_14.6_14.81
# answer_true: 14.55_14.58_14.61_14.58_14.8
# messages: user: Forecast the last 5 data points in the time column using Prophet model
# assistant: {"output": "14.57_14.6_14.62_14.6_14.81"}
# steps: [{'name': 'forecast_last_n_data', 'input': None, 'output': '[14.57, 14.6, 14.62, 14.6, 14.81]', 'args': '{"file_path":"../../data/melbourne_temp.csv","model_name":"prophet","forecast_horizon":5}'}]
# **************************************************
# ==================================================
# Question file: medium_questions.csv; File: nyc_taxi.csv; Accuracy: 0.875
# ==================================================
# question: Does the dataset show any autocorrelation?
# answer_pred: Yes.
# answer_true: Yes
# messages: user: Does the dataset show any autocorrelation?
# assistant: Yes.
# steps: [{'name': 'get_index_by_calc_acf_or_pacf', 'input': None, 'output': '1', 'args': '{"file_path":"../../data/nyc_taxi.csv","col_name":"target_col","start_lag":1,"end_lag":30,"type_of_correlation":"acf","return_max_or_min":"max"}'}]
# **************************************************
# question: Which lagging value has the weakest absolute correlation with the target variable among the values from 1 to 10 if we don't accounting for any influence from other data points?
# answer_pred: 10.0
# answer_true: 6.0
# messages: user: Which lagging value has the weakest absolute correlation with the target variable among the values from 1 to 10 if we don't accounting for any influence from other data points?
# assistant: {"output": "10"}
# steps: [{'name': 'get_index_by_calc_acf_or_pacf', 'input': None, 'output': '10', 'args': '{"file_path":"../../data/nyc_taxi.csv","col_name":"target_col","start_lag":1,"end_lag":10,"type_of_correlation":"acf","return_max_or_min":"min"}'}]
# **************************************************

# %%
df_result
# Out:
#     completion_tokens  prompt_tokens  total_tokens  \
# 0                  46           4341          4387
# 1                  46           4341          4387
# 2                  46           4341          4387
# 3                  47           4342          4389
# 4                  46           4343          4389
# ..                ...            ...           ...
# 91                 70           4422          4492
# 92                 58           4361          4419
# 93                116           4452          4568
# 94                 69           4385          4454
# 95                 69           4383          4452
#
#                                              question  \
# 0             What is the min of the target variable?
# 1             What is the max of the target variable?
# 2            What is the mean of the target variable?
# 3          What is the medium of the target variable?
# 4   What is the standard deviation of the target v...
# ..                                                ...
# 91  Which lagging value has the weakest absolute c...
# 92   What is the average in the first 10 data points?
# 93  What is the total of the maximum of the first ...
# 94  Forecast the last 5 data points in the time co...
# 95  Forecast the last 5 data points in the time co...
#
#                                      answer_pred  \
# 0                                          104.0
# 1                                          622.0
# 2                                          280.3
# 3                                          265.5
# 4                                         119.97
# ..                                           ...
# 91                                          10.0
# 92                                        4534.2
# 93                                       34135.0
# 94       23719.0_23719.0_23719.0_23719.0_23719.0
# 95  22139.22_21009.81_19774.62_18500.49_17202.22
#
#                                              messages  \
# 0   [user: What is the min of the target variable?...
# 1   [user: What is the max of the target variable?...
# 2   [user: What is the mean of the target variable...
# 3   [user: What is the medium of the target variab...
# 4   [user: What is the standard deviation of the t...
# ..                                                ...
# 91  [user: Which lagging value has the weakest abs...
# 92  [user: What is the average in the first 10 dat...
# 93  [user: What is the total of the maximum of the...
# 94  [user: Forecast the last 5 data points in the ...
# 95  [user: Forecast the last 5 data points in the ...
#
#                                                 steps attachments  \
# 0   [{'name': 'get_descriptive_statistics', 'input...          []
# 1   [{'name': 'get_descriptive_statistics', 'input...          []
# 2   [{'name': 'get_descriptive_statistics', 'input...          []
# 3   [{'name': 'get_descriptive_statistics', 'input...          []
# 4   [{'name': 'get_descriptive_statistics', 'input...          []
# ..                                                ...         ...
# 91  [{'name': 'get_index_by_calc_acf_or_pacf', 'in...          []
# 92  [{'name': 'get_descriptive_statistics', 'input...          []
# 93  [{'name': 'get_descriptive_statistics', 'input...          []
# 94  [{'name': 'forecast_last_n_data', 'input': Non...          []
# 95  [{'name': 'forecast_last_n_data', 'input': Non...          []
#
#     execution_time_s                file         question_file  \
# 0                  9  air_passengers.csv    easy_questions.csv
# 1                 13  air_passengers.csv    easy_questions.csv
# 2                  8  air_passengers.csv    easy_questions.csv
# 3                  5  air_passengers.csv    easy_questions.csv
# 4                  4  air_passengers.csv    easy_questions.csv
# ..               ...                 ...                   ...
# 91                 3        nyc_taxi.csv  medium_questions.csv
# 92                 6        nyc_taxi.csv  medium_questions.csv
# 93                 4        nyc_taxi.csv  medium_questions.csv
# 94                 4        nyc_taxi.csv  medium_questions.csv
# 95                 7        nyc_taxi.csv  medium_questions.csv
#
#                                      answer_true
# 0                                          104.0
# 1                                          622.0
# 2                                          280.3
# 3                                          265.5
# 4                                         119.97
# ..                                           ...
# 91                                           6.0
# 92                                        4534.2
# 93                                       34135.0
# 94       23719.0_23719.0_23719.0_23719.0_23719.0
# 95  22139.22_21009.81_19774.62_18500.49_17202.22
#
# [96 rows x 12 columns]

# %%
with pd.option_context("display.max_rows", None, "display.max_columns", None):
    display(df_result.groupby(["question_file", "file"]).describe())
# Out:
#                                         completion_tokens                      \
#                                                     count     mean        std
# question_file        file
# easy_questions.csv   air_passengers.csv              16.0  44.9375   9.412536
#                      melbourne_temp.csv              16.0  43.1875   5.623981
#                      nyc_taxi.csv                    16.0  45.5000   6.377042
# medium_questions.csv air_passengers.csv              16.0  62.6250  17.005391
#                      melbourne_temp.csv              16.0  67.6250  26.595426
#                      nyc_taxi.csv                    16.0  66.5000  17.196899
#
#                                                                          \
#                                           min   25%   50%    75%    max
# question_file        file
# easy_questions.csv   air_passengers.csv  34.0  39.0  46.0  47.00   75.0
#                      melbourne_temp.csv  34.0  39.0  45.5  46.25   55.0
#                      nyc_taxi.csv        35.0  40.0  47.5  48.25   56.0
# medium_questions.csv air_passengers.csv  43.0  53.5  63.0  69.00  113.0
#                      melbourne_temp.csv  40.0  53.5  63.0  69.00  140.0
#                      nyc_taxi.csv        41.0  57.5  67.5  70.00  116.0
#
#                                         prompt_tokens                         \
#                                                 count       mean         std
# question_file        file
# easy_questions.csv   air_passengers.csv          16.0  4482.3125  567.140396
#                      melbourne_temp.csv          16.0  4341.5625    5.773142
#                      nyc_taxi.csv                16.0  4345.0000    6.418723
# medium_questions.csv air_passengers.csv          16.0  4514.5625  557.136365
#                      melbourne_temp.csv          16.0  4519.3750  556.123353
#                      nyc_taxi.csv                16.0  4658.8125  756.521356
#
#                                                                            \
#                                             min      25%     50%      75%
# question_file        file
# easy_questions.csv   air_passengers.csv  4333.0  4337.75  4341.0  4343.25
#                      melbourne_temp.csv  4333.0  4338.00  4341.0  4343.25
#                      nyc_taxi.csv        4337.0  4341.00  4344.5  4347.25
# medium_questions.csv air_passengers.csv  4338.0  4359.25  4372.5  4397.00
#                      melbourne_temp.csv  4332.0  4362.25  4376.0  4402.50
#                      nyc_taxi.csv        4343.0  4365.50  4384.0  4405.50
#
#                                                 total_tokens             \
#                                             max        count       mean
# question_file        file
# easy_questions.csv   air_passengers.csv  6609.0         16.0  4527.2500
#                      melbourne_temp.csv  4356.0         16.0  4384.7500
#                      nyc_taxi.csv        4359.0         16.0  4390.5000
# medium_questions.csv air_passengers.csv  6601.0         16.0  4577.1875
#                      melbourne_temp.csv  6601.0         16.0  4587.0000
#                      nyc_taxi.csv        6608.0         16.0  4725.3125
#
#                                                                               \
#                                                 std     min      25%     50%
# question_file        file
# easy_questions.csv   air_passengers.csv  575.208774  4369.0  4375.50  4387.0
#                      melbourne_temp.csv   10.109402  4368.0  4376.00  4387.0
#                      nyc_taxi.csv         12.345039  4375.0  4379.50  4392.0
# medium_questions.csv air_passengers.csv  562.503241  4381.0  4411.25  4435.0
#                      melbourne_temp.csv  561.172938  4372.0  4413.00  4439.0
#                      nyc_taxi.csv        762.306825  4384.0  4426.50  4449.0
#
#                                                          execution_time_s  \
#                                              75%     max            count
# question_file        file
# easy_questions.csv   air_passengers.csv  4389.50  6684.0             16.0
#                      melbourne_temp.csv  4389.50  4411.0             16.0
#                      nyc_taxi.csv        4395.25  4415.0             16.0
# medium_questions.csv air_passengers.csv  4466.00  6680.0             16.0
#                      melbourne_temp.csv  4471.50  6680.0             16.0
#                      nyc_taxi.csv        4475.50  6689.0             16.0
#
#                                                                           \
#                                            mean       std  min  25%  50%
# question_file        file
# easy_questions.csv   air_passengers.csv  5.1250  2.801785  3.0  3.0  4.0
#                      melbourne_temp.csv  4.3750  1.784190  2.0  3.0  4.0
#                      nyc_taxi.csv        3.8125  0.750000  3.0  3.0  4.0
# medium_questions.csv air_passengers.csv  4.2500  1.770122  3.0  3.0  4.0
#                      melbourne_temp.csv  4.0625  1.569235  3.0  3.0  3.0
#                      nyc_taxi.csv        5.1250  2.918333  3.0  3.0  4.0
#
#
#                                           75%   max
# question_file        file
# easy_questions.csv   air_passengers.csv  5.50  13.0
#                      melbourne_temp.csv  5.25   8.0
#                      nyc_taxi.csv        4.00   5.0
# medium_questions.csv air_passengers.csv  4.00   8.0
#                      melbourne_temp.csv  5.00   8.0
#                      nyc_taxi.csv        6.00  14.0

# %% [markdown]
# ## Run one question

# %%
# list all assistants
assistant.list_all_assistants()
# Out:
#                               id  created_at description  \
# 0  asst_vOt2vULsZnzSZfqASNWCA1uv  1735007676        None
# 1  asst_qXfVisu4RHEIYa5Qs4L3I1Xa  1735007596        None
# 2  asst_kFyF79QuX27kMYRnguWb80n9  1735007502        None
# 3  asst_VGmOogPrbDPXHIJeUbVmWWzZ  1734137131        None
# 4  asst_0Qc1dyLAY7XD3dKLqIkNJ45l  1734137012        None
# 5  asst_hTacjFmXp0wJW7cTacgiIaVm  1734136870        None
# 6  asst_x4c0gSGzdmoljHa4DrmZjPZO  1734135165        None
#
#                                         instructions metadata   model  \
# 0  You are a data scientist in univariate time se...       {}  gpt-4o
# 1  You are a data scientist in univariate time se...       {}  gpt-4o
# 2  You are a data scientist in univariate time se...       {}  gpt-4o
# 3  You are a data scientist in univariate time se...       {}  gpt-4o
# 4  You are a data scientist in univariate time se...       {}  gpt-4o
# 5  You are a data scientist in univariate time se...       {}  gpt-4o
# 6  You are a python expert in univariate time ser...       {}  gpt-4o
#
#                               name     object  \
# 0         customized_func_nyc_taxi  assistant
# 1   customized_func_melbourne_temp  assistant
# 2   customized_func_air_passengers  assistant
# 3        code_interpreter_nyc_taxi  assistant
# 4  code_interpreter_melbourne_temp  assistant
# 5  code_interpreter_air_passengers  assistant
# 6   code_interpreter_nyc_taxi_plot  assistant
#
#                                                tools response_format  \
# 0  [{'function': {'name': 'get_time_col_and_targe...            auto
# 1  [{'function': {'name': 'get_time_col_and_targe...            auto
# 2  [{'function': {'name': 'get_time_col_and_targe...            auto
# 3                     [{'type': 'code_interpreter'}]            auto
# 4                     [{'type': 'code_interpreter'}]            auto
# 5                     [{'type': 'code_interpreter'}]            auto
# 6                     [{'type': 'code_interpreter'}]            auto
#
#    temperature                                     tool_resources  top_p
# 0          0.0                                                 {}    1.0
# 1          0.0                                                 {}    1.0
# 2          0.0                                                 {}    1.0
# 3          0.0  {'code_interpreter': {'file_ids': ['assistant-...    1.0
# 4          0.0  {'code_interpreter': {'file_ids': ['assistant-...    1.0
# 5          0.0  {'code_interpreter': {'file_ids': ['assistant-...    1.0
# 6          0.0  {'code_interpreter': {'file_ids': ['assistant-...    1.0

# %%
question = "Forecast the last 5 data points in the time column using prophet model."
result = assistant.ask_a_question(
    question=question, assistant_id="asst_PprPG3wDRy0vhncihJgfGKbT", tools=TOOLS
)
result
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# Cell In[14], line 2
#       1 question = "Forecast the last 5 data points in the time column using prophet model."
# ----> 2 result = assistant.ask_a_question(
#       3     question=question, assistant_id="asst_PprPG3wDRy0vhncihJgfGKbT", tools=TOOLS
#       4 )
#       5 result
#
# File ~/Projects/Internal/llm_time_series_analysis/notebooks/utils/assistants.py:185, in AzureOpenAIAssistant.ask_a_question(self, question, assistant_id, tools)
#     167 """Ask a question to the assistant and return the response
#     168
#     169 Args:
#    (...)
#     182             completion_tokens, prompt_tokens, total_tokens, question, answer_pred, message, code, attachment, execution_time_s
#     183 """
#     184 # create a and run a thread
# --> 185 run = self.client.beta.threads.create_and_run(
#     186     assistant_id=assistant_id,
#     187     thread={"messages": [{"role": "user", "content": question}]},
#     188 )
#     190 # looping until the run completes or fails
#     191 while True:
#
# File ~/miniconda3/envs/test/lib/python3.12/site-packages/openai/_utils/_utils.py:275, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     273             msg = f"Missing required argument: {quote(missing[0])}"
#     274     raise TypeError(msg)
# --> 275 return func(*args, **kwargs)
#
# File ~/miniconda3/envs/test/lib/python3.12/site-packages/openai/resources/beta/threads/threads.py:686, in Threads.create_and_run(self, assistant_id, instructions, max_completion_tokens, max_prompt_tokens, metadata, model, parallel_tool_calls, response_format, stream, temperature, thread, tool_choice, tool_resources, tools, top_p, truncation_strategy, extra_headers, extra_query, extra_body, timeout)
#     658 @required_args(["assistant_id"], ["assistant_id", "stream"])
#     659 def create_and_run(
#     660     self,
#    (...)
#     683     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     684 ) -> Run | Stream[AssistantStreamEvent]:
#     685     extra_headers = {"OpenAI-Beta": "assistants=v2", **(extra_headers or {})}
# --> 686     return self._post(
#     687         "/threads/runs",
#     688         body=maybe_transform(
#     689             {
#     690                 "assistant_id": assistant_id,
#     691                 "instructions": instructions,
#     692                 "max_completion_tokens": max_completion_tokens,
#     693                 "max_prompt_tokens": max_prompt_tokens,
#     694                 "metadata": metadata,
#     695                 "model": model,
#     696                 "parallel_tool_calls": parallel_tool_calls,
#     697                 "response_format": response_format,
#     698                 "stream": stream,
#     699                 "temperature": temperature,
#     700                 "thread": thread,
#     701                 "tool_choice": tool_choice,
#     702                 "tool_resources": tool_resources,
#     703                 "tools": tools,
#     704                 "top_p": top_p,
#     705                 "truncation_strategy": truncation_strategy,
#     706             },
#     707             thread_create_and_run_params.ThreadCreateAndRunParams,
#     708         ),
#     709         options=make_request_options(
#     710             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     711         ),
#     712         cast_to=Run,
#     713         stream=stream or False,
#     714         stream_cls=Stream[AssistantStreamEvent],
#     715     )
#
# File ~/miniconda3/envs/test/lib/python3.12/site-packages/openai/_base_client.py:1278, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1264 def post(
#    1265     self,
#    1266     path: str,
#    (...)
#    1273     stream_cls: type[_StreamT] | None = None,
#    1274 ) -> ResponseT | _StreamT:
#    1275     opts = FinalRequestOptions.construct(
#    1276         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1277     )
# -> 1278     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/miniconda3/envs/test/lib/python3.12/site-packages/openai/_base_client.py:955, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     952 else:
#     953     retries_taken = 0
# --> 955 return self._request(
#     956     cast_to=cast_to,
#     957     options=options,
#     958     stream=stream,
#     959     stream_cls=stream_cls,
#     960     retries_taken=retries_taken,
#     961 )
#
# File ~/miniconda3/envs/test/lib/python3.12/site-packages/openai/_base_client.py:1059, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1056         err.response.read()
#    1058     log.debug("Re-raising status error")
# -> 1059     raise self._make_status_error_from_response(err.response) from None
#    1061 return self._process_response(
#    1062     cast_to=cast_to,
#    1063     options=options,
#    (...)
#    1067     retries_taken=retries_taken,
#    1068 )
#
# NotFoundError: Error code: 404 - {'error': {'message': "No assistant found with id 'asst_PprPG3wDRy0vhncihJgfGKbT'.", 'type': 'invalid_request_error', 'param': None, 'code': None}}
