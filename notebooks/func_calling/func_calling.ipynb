# %% [markdown]
# This notebooks shows how to use [OpenAI assistant](https://platform.openai.com/docs/guides/function-calling) to do function calling.
# - steps:
#   - create an assistant (LLM + a lot of predefined func)
#   - call LLM to see which predefined func to use and what are the input params
#   - return the results to LLM
#   - get the answer from LLM

# %%
from openai import AzureOpenAI
from dotenv import load_dotenv
import os
import pandas as pd
from jinja2 import Environment, FileSystemLoader
from pathlib import Path
import sys
import time

module_path = os.path.abspath(os.path.join(".."))
if module_path not in sys.path:
    sys.path.append(module_path)

from utils.utils import convert_types, eval
from utils.vars import DATA_DIR, DATASET_FILES, QUESTION_FILES
from utils.assistants import AzureOpenAIAssistant
from utils.customized_func_tools import (
    TOOLS,
)

load_dotenv()
ASSISTANT_NAME_PREFIX = "customized_func"

# %%
# get the prompt template
prompt_path = "prompts/prompt.jinja2"
# get the client object
client = AzureOpenAI(
    api_key=os.getenv("AZURE_OPENAI_API_KEY"),
    api_version="2025-03-01-preview",  # different from assistant
    azure_endpoint=os.getenv("AZURE_OPENAI_ENDPOINT"),
)
assistant = AzureOpenAIAssistant(client=client)

# %%
display(assistant.list_all_assistants())
# Out:
#                               id  created_at description  \
# 0  asst_tihDxvHK3TSBDoabAYk4nrpB  1747654063        None
# 1  asst_G6lW78uX2ZCBvPhkTNkpCY0P  1747654004        None
# 2  asst_PyqoRwGSDRSliYUZFpuyRQGT  1747653943        None
# 3  asst_zEURRNR06p0UK9YYlNLNdDPt  1747185462        None
# 4  asst_yb8Ab2f244pJlmrZQjn8uTCO  1747185389        None
# 5  asst_WHmQuNTDclu5t75pTbZh48bT  1747185310        None
# 6  asst_x4c0gSGzdmoljHa4DrmZjPZO  1734135165        None
#
#                                         instructions metadata   model  \
# 0  You are a data scientist specializing in time ...       {}  gpt-4o
# 1  You are a data scientist specializing in time ...       {}  gpt-4o
# 2  You are a data scientist specializing in time ...       {}  gpt-4o
# 3  You are a data scientist specializing in time ...       {}  gpt-4o
# 4  You are a data scientist specializing in time ...       {}  gpt-4o
# 5  You are a data scientist specializing in time ...       {}  gpt-4o
# 6  You are a python expert in univariate time ser...       {}  gpt-4o
#
#                               name     object  \
# 0         customized_func_nyc_taxi  assistant
# 1   customized_func_melbourne_temp  assistant
# 2   customized_func_air_passengers  assistant
# 3        code_interpreter_nyc_taxi  assistant
# 4  code_interpreter_melbourne_temp  assistant
# 5  code_interpreter_air_passengers  assistant
# 6   code_interpreter_nyc_taxi_plot  assistant
#
#                                                tools response_format  \
# 0  [{'function': {'name': 'get_time_col_and_targe...            auto
# 1  [{'function': {'name': 'get_time_col_and_targe...            auto
# 2  [{'function': {'name': 'get_time_col_and_targe...            auto
# 3                     [{'type': 'code_interpreter'}]            auto
# 4                     [{'type': 'code_interpreter'}]            auto
# 5                     [{'type': 'code_interpreter'}]            auto
# 6                     [{'type': 'code_interpreter'}]            auto
#
#    temperature                                     tool_resources  top_p
# 0          0.0                                                 {}    1.0
# 1          0.0                                                 {}    1.0
# 2          0.0                                                 {}    1.0
# 3          0.0  {'code_interpreter': {'file_ids': ['assistant-...    1.0
# 4          0.0  {'code_interpreter': {'file_ids': ['assistant-...    1.0
# 5          0.0  {'code_interpreter': {'file_ids': ['assistant-...    1.0
# 6          0.0  {'code_interpreter': {'file_ids': ['assistant-...    1.0

# %%
# delete assistant
assistant.delete_assistant(name=f"{ASSISTANT_NAME_PREFIX}_nyc_taxi")
assistant.delete_assistant(name=f"{ASSISTANT_NAME_PREFIX}_melbourne_temp")
assistant.delete_assistant(name=f"{ASSISTANT_NAME_PREFIX}_air_passengers")

display(assistant.list_all_assistants())
# Out:
#                               id  created_at description  \
# 0  asst_zEURRNR06p0UK9YYlNLNdDPt  1747185462        None
# 1  asst_yb8Ab2f244pJlmrZQjn8uTCO  1747185389        None
# 2  asst_WHmQuNTDclu5t75pTbZh48bT  1747185310        None
# 3  asst_x4c0gSGzdmoljHa4DrmZjPZO  1734135165        None
#
#                                         instructions metadata   model  \
# 0  You are a data scientist specializing in time ...       {}  gpt-4o
# 1  You are a data scientist specializing in time ...       {}  gpt-4o
# 2  You are a data scientist specializing in time ...       {}  gpt-4o
# 3  You are a python expert in univariate time ser...       {}  gpt-4o
#
#                               name     object                           tools  \
# 0        code_interpreter_nyc_taxi  assistant  [{'type': 'code_interpreter'}]
# 1  code_interpreter_melbourne_temp  assistant  [{'type': 'code_interpreter'}]
# 2  code_interpreter_air_passengers  assistant  [{'type': 'code_interpreter'}]
# 3   code_interpreter_nyc_taxi_plot  assistant  [{'type': 'code_interpreter'}]
#
#   response_format  temperature  \
# 0            auto          0.0
# 1            auto          0.0
# 2            auto          0.0
# 3            auto          0.0
#
#                                       tool_resources  top_p
# 0  {'code_interpreter': {'file_ids': ['assistant-...    1.0
# 1  {'code_interpreter': {'file_ids': ['assistant-...    1.0
# 2  {'code_interpreter': {'file_ids': ['assistant-...    1.0
# 3  {'code_interpreter': {'file_ids': ['assistant-...    1.0

# %% [markdown]
# ## Run 3 files x all questions

# %%
# cons
# cannot pass a lot of values to the prompt due to token limit
# really need to design the function properly

# %%
# read the prompt
instruction = (
    Environment(loader=FileSystemLoader(".")).get_template(prompt_path).render()
)

df_result = []

for question_path in QUESTION_FILES:
    question_path = Path(question_path)
    print(f"Question file: {question_path.name}")
    # read questions
    df_questions = pd.read_csv(DATA_DIR / question_path)
    # loop through each csv file
    for dataset_path in DATASET_FILES:
        dataset_path = Path(DATA_DIR, dataset_path)
        print(f"file: {dataset_path.name}")

        assistant_id = assistant.create_or_retrieve(
            prompt_path=prompt_path,
            assistant_name=f"{ASSISTANT_NAME_PREFIX}_{dataset_path.stem}",
            tools=TOOLS,
            tool_resources=None,
            prompt_args={"dataset_path": dataset_path},
        )
        # loop through questions
        for _, row in df_questions.iterrows():
            question = row["question"]
            answer_true = row[dataset_path.name]

            start_time = time.time()

            result = assistant.ask_a_question(
                question=question, assistant_id=assistant_id, tools=TOOLS
            )

            df_result.append(
                {
                    **result,
                    "question_file": question_path.name,
                    "question": question,
                    "execution_time_s": round(time.time() - start_time, 2),
                    "dataset_file": dataset_path.name,
                    "org_answer_true": answer_true,
                }
            )
# Out:
# Question file: easy_questions.csv
# file: air_passengers.csv
# file: melbourne_temp.csv
# file: nyc_taxi.csv
# Question file: medium_questions.csv
# file: air_passengers.csv
# file: melbourne_temp.csv
# file: nyc_taxi.csv
# Question file: hard_questions.csv
# file: air_passengers.csv
# file: melbourne_temp.csv
# file: nyc_taxi.csv

# %%
# eval
df_result = pd.DataFrame(df_result)

df_result["answer_pred"] = df_result["org_answer_pred"].apply(
    lambda x: convert_types(x)
)
df_result["answer_true"] = df_result["org_answer_true"].apply(
    lambda x: convert_types(x)
)

# loop through each file
eval(df=df_result, details=True)
# Out:
# ==================================================
# Question file: easy_questions.csv; Dataset File: air_passengers.csv; Accuracy: 1.0
# ==================================================
# ==================================================
# Question file: easy_questions.csv; Dataset File: melbourne_temp.csv; Accuracy: 1.0
# ==================================================
# ==================================================
# Question file: easy_questions.csv; Dataset File: nyc_taxi.csv; Accuracy: 1.0
# ==================================================
# ==================================================
# Question file: medium_questions.csv; Dataset File: air_passengers.csv; Accuracy: 0.9
# ==================================================
# question: what is the typical value?
# answer_pred: 265.5
# answer_true: 280.3
# messages: user: what is the typical value?
# assistant: {"output": "265.5"}
# steps: [{'name': 'get_descriptive_statistics', 'input': None, 'output': '265.5', 'args': '{"file_path":"../../data/air_passengers.csv","statistic_name":"50%","col_name":"target_col"}'}]
# **************************************************
# ==================================================
# Question file: medium_questions.csv; Dataset File: melbourne_temp.csv; Accuracy: 1.0
# ==================================================
# ==================================================
# Question file: medium_questions.csv; Dataset File: nyc_taxi.csv; Accuracy: 0.8
# ==================================================
# question: what is the typical value?
# answer_pred: 16778.0
# answer_true: 15137.57
# messages: user: what is the typical value?
# assistant: {"output": "16778.0"}
# steps: [{'name': 'get_descriptive_statistics', 'input': None, 'output': '16778.0', 'args': '{\n  "file_path": "../../data/nyc_taxi.csv",\n  "statistic_name": "50%",\n  "col_name": "target_col"\n}'}]
# **************************************************
# question: Give me the total amount when the time is Tuesday.
# answer_pred: 21291464.0
# answer_true: 21291463.0
# messages: user: Give me the total amount when the time is Tuesday.
# assistant: {"output": "21291464.0"}
# steps: [{'name': 'get_descriptive_statistics', 'input': None, 'output': '21291464.0', 'args': '{"file_path":"../../data/nyc_taxi.csv","statistic_name":"sum","col_name":"target_col","selected_day_in_a_week":1}'}]
# **************************************************
# ==================================================
# Question file: hard_questions.csv; Dataset File: air_passengers.csv; Accuracy: 0.7
# ==================================================
# question: Are there any constantly increasing or decreasing trend in the data over time?
# answer_pred: 0.99
# answer_true: yes
# messages: user: Are there any constantly increasing or decreasing trend in the data over time?
# assistant: {"output": "0.99"}
# steps: [{'name': 'get_time_col_and_target_col', 'input': None, 'output': "{'target_col': 'y', 'time_col': 'ds'}", 'args': '{"file_path":"../../data/air_passengers.csv"}'}, {'name': 'get_seasonality', 'input': None, 'output': '12', 'args': '{"file_path":"../../data/air_passengers.csv","type":"seasonality_period"}'}, {'name': 'get_trend_by_pearson_correlation', 'input': None, 'output': '0.9943179911631559', 'args': '{"file_path":"../../data/air_passengers.csv","seasonality_period":12}'}]
# **************************************************
# question: Are there any seasonal patterns in the data?
# answer_pred: true
# answer_true: yes
# messages: user: Are there any seasonal patterns in the data?
# assistant: {"output": "True"}
# steps: [{'name': 'get_seasonality', 'input': None, 'output': 'True', 'args': '{"file_path":"../../data/air_passengers.csv","type":"has_seasonality"}'}]
# **************************************************
# question: Is there a strong correlation with weekends(Saturday and Sunday)?
# answer_pred: -0.03
# answer_true: no
# messages: user: Is there a strong correlation with weekends(Saturday and Sunday)?
# assistant: {"output": "-0.03"}
# steps: [{'name': 'calculate_weekend_pearson_correlation', 'input': None, 'output': '-0.030280299924021536', 'args': '{"file_path":"../../data/air_passengers.csv"}'}]
# **************************************************
# ==================================================
# Question file: hard_questions.csv; Dataset File: melbourne_temp.csv; Accuracy: 0.6
# ==================================================
# question: Are there any constantly increasing or decreasing trend in the data over time?
# answer_pred: 0.02
# answer_true: no
# messages: user: Are there any constantly increasing or decreasing trend in the data over time?
# assistant: {"output": "0.02"}
# steps: [{'name': 'get_time_col_and_target_col', 'input': None, 'output': "{'target_col': 'Daily minimum temperatures', 'time_col': 'Date'}", 'args': '{"file_path":"../../data/melbourne_temp.csv"}'}, {'name': 'get_seasonality', 'input': None, 'output': '13', 'args': '{"file_path":"../../data/melbourne_temp.csv","type":"seasonality_period"}'}, {'name': 'get_trend_by_pearson_correlation', 'input': None, 'output': '0.018949890560801517', 'args': '{"file_path":"../../data/melbourne_temp.csv","seasonality_period":13}'}]
# **************************************************
# question: Are there any seasonal patterns in the data?
# answer_pred: true
# answer_true: yes
# messages: user: Are there any seasonal patterns in the data?
# assistant: {"output": "True"}
# steps: [{'name': 'get_seasonality', 'input': None, 'output': 'True', 'args': '{"file_path":"../../data/melbourne_temp.csv","type":"has_seasonality"}'}]
# **************************************************
# question: Which method is the best for forecasting the last data point: the naive method or the average method?
# answer_pred: naive
# answer_true: average
# messages: user: Which method is the best for forecasting the last data point: the naive method or the average method?
# assistant: {"output":"naive"}
# steps: [{'name': 'retrieve_a_row_by_index', 'input': None, 'output': "{'time_col': Timestamp('1990-12-31 00:00:00'), 'target_col': 13.0}", 'args': '{"file_path":"../../data/melbourne_temp.csv","index":-1}'}, {'name': 'get_forecasting', 'input': None, 'output': '13.0', 'args': '{"file_path": "../../data/melbourne_temp.csv", "model_name": "naive", "forecast_time": "1990-12-31"}'}, {'name': 'get_forecasting', 'input': None, 'output': '11.18', 'args': '{"file_path": "../../data/melbourne_temp.csv", "model_name": "average", "forecast_time": "1990-12-31"}'}]
# **************************************************
# question: Is there a strong correlation with weekends(Saturday and Sunday)?
# answer_pred: -0.02
# answer_true: no
# messages: user: Is there a strong correlation with weekends(Saturday and Sunday)?
# assistant: {"output": "-0.02"}
# steps: [{'name': 'calculate_weekend_pearson_correlation', 'input': None, 'output': '-0.016403951291544535', 'args': '{"file_path":"../../data/melbourne_temp.csv"}'}]
# **************************************************
# ==================================================
# Question file: hard_questions.csv; Dataset File: nyc_taxi.csv; Accuracy: 0.7
# ==================================================
# question: Are there any constantly increasing or decreasing trend in the data over time?
# answer_pred: -0.08
# answer_true: no
# messages: user: Are there any constantly increasing or decreasing trend in the data over time?
# assistant: {"output": "-0.08"}
# steps: [{'name': 'get_time_col_and_target_col', 'input': None, 'output': "{'target_col': '#Passengers', 'time_col': 'time'}", 'args': '{"file_path":"../../data/nyc_taxi.csv"}'}, {'name': 'get_seasonality', 'input': None, 'output': '48', 'args': '{"file_path":"../../data/nyc_taxi.csv","type":"seasonality_period"}'}, {'name': 'get_trend_by_pearson_correlation', 'input': None, 'output': '-0.07612466470085219', 'args': '{"file_path":"../../data/nyc_taxi.csv","seasonality_period":48}'}]
# **************************************************
# question: Are there any seasonal patterns in the data?
# answer_pred: true
# answer_true: yes
# messages: user: Are there any seasonal patterns in the data?
# assistant: {"output":"True"}
# steps: [{'name': 'get_seasonality', 'input': None, 'output': 'True', 'args': '{"file_path":"../../data/nyc_taxi.csv","type":"has_seasonality"}'}]
# **************************************************
# question: Is there a strong correlation with weekends(Saturday and Sunday)?
# answer_pred: 0.07
# answer_true: no
# messages: user: Is there a strong correlation with weekends(Saturday and Sunday)?
# assistant: {"output":"0.07"}
# steps: [{'name': 'calculate_weekend_pearson_correlation', 'input': None, 'output': '0.0688705012665466', 'args': '{"file_path":"../../data/nyc_taxi.csv"}'}]
# **************************************************

# %%
# check detailed observability metrics
df_result.groupby(["question_file", "dataset_file"])[
    ["total_tokens", "execution_time_s"]
].describe()[[("total_tokens", "mean"), ("execution_time_s", "mean")]].round(2)
# Out:
#                                         total_tokens execution_time_s
#                                                 mean             mean
# question_file        dataset_file
# easy_questions.csv   air_passengers.csv       5109.2             5.94
#                      melbourne_temp.csv       5113.7             6.92
#                      nyc_taxi.csv             5117.1             7.04
# hard_questions.csv   air_passengers.csv       5156.4             6.13
#                      melbourne_temp.csv       4944.1             6.40
#                      nyc_taxi.csv             5177.6             5.99
# medium_questions.csv air_passengers.csv       3918.0             5.41
#                      melbourne_temp.csv       3919.5             5.88
#                      nyc_taxi.csv             4129.4             5.11

# %%
# check overall observability metrics
df_result.describe().round(2)
# Out:
#        completion_tokens  prompt_tokens  total_tokens  \
# count              90.00          90.00         90.00
# mean               59.76        4671.91       4731.67
# std                30.11        1211.75       1233.52
# min                29.00        3832.00       3862.00
# 25%                38.00        3843.25       3880.00
# 50%                46.00        3861.00       3910.00
# 75%                72.75        5857.75       5930.00
# max               188.00        7963.00       8077.00
#
#        execution_time_s_in_code_interpreter  execution_time_s
# count                                 90.00             90.00
# mean                                   4.94              6.09
# std                                    2.47              2.45
# min                                    2.00              3.68
# 25%                                    3.00              4.36
# 50%                                    4.00              5.10
# 75%                                    6.00              6.89
# max                                   15.00             16.17

# %%
with pd.option_context("display.max_rows", None, "display.max_columns", None):
    display(df_result.groupby(["dataset_file"]).describe())
# Out:
#                    completion_tokens                                           \
#                                count       mean        std   min    25%   50%
# dataset_file
# air_passengers.csv              30.0  58.833333  29.996647  29.0  38.00  45.5
# melbourne_temp.csv              30.0  57.333333  26.028278  30.0  38.25  45.5
# nyc_taxi.csv                    30.0  63.100000  34.458721  32.0  39.00  50.0
#
#                                  prompt_tokens                            \
#                       75%    max         count         mean          std
# dataset_file
# air_passengers.csv  72.00  155.0          30.0  4669.033333  1262.358042
# melbourne_temp.csv  72.00  130.0          30.0  4601.766667  1127.150410
# nyc_taxi.csv        75.75  188.0          30.0  4744.933333  1277.347168
#
#                                                              total_tokens  \
#                        min      25%     50%      75%     max        count
# dataset_file
# air_passengers.csv  3832.0  3841.25  3860.5  5853.00  7950.0         30.0
# melbourne_temp.csv  3832.0  3842.00  3860.5  5858.00  7918.0         30.0
# nyc_taxi.csv        3835.0  3844.75  3863.5  5860.75  7963.0         30.0
#
#                                                                                \
#                            mean          std     min      25%     50%     75%
# dataset_file
# air_passengers.csv  4727.866667  1284.279987  3862.0  3878.25  3907.0  5925.0
# melbourne_temp.csv  4659.100000  1146.223705  3863.0  3880.00  3907.0  5930.0
# nyc_taxi.csv        4808.033333  1301.905592  3869.0  3882.00  3913.0  5936.5
#
#                            execution_time_s_in_code_interpreter            \
#                        max                                count      mean
# dataset_file
# air_passengers.csv  8060.0                                 30.0  4.600000
# melbourne_temp.csv  8019.0                                 30.0  5.266667
# nyc_taxi.csv        8077.0                                 30.0  4.966667
#
#                                                         execution_time_s  \
#                          std  min   25%  50%  75%   max            count
# dataset_file
# air_passengers.csv  2.077797  2.0  3.00  4.0  5.0  12.0             30.0
# melbourne_temp.csv  3.279333  2.0  3.00  4.0  6.0  15.0             30.0
# nyc_taxi.csv        1.865907  3.0  3.25  4.0  6.0   9.0             30.0
#
#
#                         mean       std   min     25%    50%     75%    max
# dataset_file
# air_passengers.csv  5.825333  2.063473  3.78  4.1700  5.090  6.8275  13.32
# melbourne_temp.csv  6.398667  3.234532  3.77  4.2475  5.105  6.7700  16.17
# nyc_taxi.csv        6.046333  1.859250  3.68  4.9375  5.220  7.9250  10.43

# %% [markdown]
# ## Run one question

# %%
# list all assistants
assistant.list_all_assistants()
# Out:
#                               id  created_at description  \
# 0  asst_ezGHJBYCFh3nx0JdQtUrBsdw  1747655525        None
# 1  asst_KdIz1fUmJQnC9f0omQb1rGBk  1747655455        None
# 2  asst_VjGjUNyjAj31MAgDbGbmgjlh  1747655395        None
# 3  asst_zEURRNR06p0UK9YYlNLNdDPt  1747185462        None
# 4  asst_yb8Ab2f244pJlmrZQjn8uTCO  1747185389        None
# 5  asst_WHmQuNTDclu5t75pTbZh48bT  1747185310        None
# 6  asst_x4c0gSGzdmoljHa4DrmZjPZO  1734135165        None
#
#                                         instructions metadata   model  \
# 0  You are a data scientist specializing in time ...       {}  gpt-4o
# 1  You are a data scientist specializing in time ...       {}  gpt-4o
# 2  You are a data scientist specializing in time ...       {}  gpt-4o
# 3  You are a data scientist specializing in time ...       {}  gpt-4o
# 4  You are a data scientist specializing in time ...       {}  gpt-4o
# 5  You are a data scientist specializing in time ...       {}  gpt-4o
# 6  You are a python expert in univariate time ser...       {}  gpt-4o
#
#                               name     object  \
# 0         customized_func_nyc_taxi  assistant
# 1   customized_func_melbourne_temp  assistant
# 2   customized_func_air_passengers  assistant
# 3        code_interpreter_nyc_taxi  assistant
# 4  code_interpreter_melbourne_temp  assistant
# 5  code_interpreter_air_passengers  assistant
# 6   code_interpreter_nyc_taxi_plot  assistant
#
#                                                tools response_format  \
# 0  [{'function': {'name': 'get_time_col_and_targe...            auto
# 1  [{'function': {'name': 'get_time_col_and_targe...            auto
# 2  [{'function': {'name': 'get_time_col_and_targe...            auto
# 3                     [{'type': 'code_interpreter'}]            auto
# 4                     [{'type': 'code_interpreter'}]            auto
# 5                     [{'type': 'code_interpreter'}]            auto
# 6                     [{'type': 'code_interpreter'}]            auto
#
#    temperature                                     tool_resources  top_p
# 0          0.0                                                 {}    1.0
# 1          0.0                                                 {}    1.0
# 2          0.0                                                 {}    1.0
# 3          0.0  {'code_interpreter': {'file_ids': ['assistant-...    1.0
# 4          0.0  {'code_interpreter': {'file_ids': ['assistant-...    1.0
# 5          0.0  {'code_interpreter': {'file_ids': ['assistant-...    1.0
# 6          0.0  {'code_interpreter': {'file_ids': ['assistant-...    1.0

# %%
question = "Forecast the next data point using the naïve method."
result = assistant.ask_a_question(
    question=question, assistant_id="asst_ggryg6Pu49DHOFuOB6l6awG4", tools=TOOLS
)
result
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# Cell In[14], line 2
#       1 question = "Forecast the next data point using the naïve method."
# ----> 2 result = assistant.ask_a_question(
#       3     question=question, assistant_id="asst_ggryg6Pu49DHOFuOB6l6awG4", tools=TOOLS
#       4 )
#       5 result
#
# File ~/Projects/Internal/llm_time_series_analysis/notebooks/utils/assistants.py:179, in AzureOpenAIAssistant.ask_a_question(self, question, assistant_id, tools)
#     161 """Ask a question to the assistant and return the response
#     162
#     163 Args:
#    (...)    176             completion_tokens, prompt_tokens, total_tokens, question, answer_pred, message, code, attachment, execution_time_s
#     177 """
#     178 # create a and run a thread
# --> 179 run = self.client.beta.threads.create_and_run(
#     180     assistant_id=assistant_id,
#     181     thread={"messages": [{"role": "user", "content": question}]},
#     182 )
#     184 # looping until the run completes or fails
#     185 while True:
#
# File ~/miniconda3/envs/tsa/lib/python3.13/site-packages/openai/_utils/_utils.py:287, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     285             msg = f"Missing required argument: {quote(missing[0])}"
#     286     raise TypeError(msg)
# --> 287 return func(*args, **kwargs)
#
# File ~/miniconda3/envs/tsa/lib/python3.13/site-packages/openai/resources/beta/threads/threads.py:696, in Threads.create_and_run(self, assistant_id, instructions, max_completion_tokens, max_prompt_tokens, metadata, model, parallel_tool_calls, response_format, stream, temperature, thread, tool_choice, tool_resources, tools, top_p, truncation_strategy, extra_headers, extra_query, extra_body, timeout)
#     668 @required_args(["assistant_id"], ["assistant_id", "stream"])
#     669 def create_and_run(
#     670     self,
#    (...)    693     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     694 ) -> Run | Stream[AssistantStreamEvent]:
#     695     extra_headers = {"OpenAI-Beta": "assistants=v2", **(extra_headers or {})}
# --> 696     return self._post(
#     697         "/threads/runs",
#     698         body=maybe_transform(
#     699             {
#     700                 "assistant_id": assistant_id,
#     701                 "instructions": instructions,
#     702                 "max_completion_tokens": max_completion_tokens,
#     703                 "max_prompt_tokens": max_prompt_tokens,
#     704                 "metadata": metadata,
#     705                 "model": model,
#     706                 "parallel_tool_calls": parallel_tool_calls,
#     707                 "response_format": response_format,
#     708                 "stream": stream,
#     709                 "temperature": temperature,
#     710                 "thread": thread,
#     711                 "tool_choice": tool_choice,
#     712                 "tool_resources": tool_resources,
#     713                 "tools": tools,
#     714                 "top_p": top_p,
#     715                 "truncation_strategy": truncation_strategy,
#     716             },
#     717             thread_create_and_run_params.ThreadCreateAndRunParamsStreaming
#     718             if stream
#     719             else thread_create_and_run_params.ThreadCreateAndRunParamsNonStreaming,
#     720         ),
#     721         options=make_request_options(
#     722             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     723         ),
#     724         cast_to=Run,
#     725         stream=stream or False,
#     726         stream_cls=Stream[AssistantStreamEvent],
#     727     )
#
# File ~/miniconda3/envs/tsa/lib/python3.13/site-packages/openai/_base_client.py:1239, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1225 def post(
#    1226     self,
#    1227     path: str,
#    (...)   1234     stream_cls: type[_StreamT] | None = None,
#    1235 ) -> ResponseT | _StreamT:
#    1236     opts = FinalRequestOptions.construct(
#    1237         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1238     )
# -> 1239     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/miniconda3/envs/tsa/lib/python3.13/site-packages/openai/_base_client.py:1034, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1031             err.response.read()
#    1033         log.debug("Re-raising status error")
# -> 1034         raise self._make_status_error_from_response(err.response) from None
#    1036     break
#    1038 assert response is not None, "could not resolve response (should never happen)"
#
# NotFoundError: Error code: 404 - {'error': {'message': "No assistant found with id 'asst_ggryg6Pu49DHOFuOB6l6awG4'.", 'type': 'invalid_request_error', 'param': None, 'code': None}}
